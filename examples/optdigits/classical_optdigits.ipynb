# %% [markdown]
# # Classical RBM training on the OptDigits Dataset for reconstruction and classification
# This is an example on classical Gibbs training of an RBM on the OptDigits
# dataset.
# Developed by: Jose Pinilla

# %%
# Required packages
import qaml
import torch
import itertools

import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchvision.transforms as torch_transforms

# %%
################################# Hyperparameters ##############################
M,N = SHAPE = (8,8)
EPOCHS = 75
BATCH_SIZE = 1024
SUBCLASSES = [1,2,3,4]
DATA_SIZE = N*M
LABEL_SIZE = len(SUBCLASSES)
# Stochastic Gradient Descent
learning_rate = 0.1
weight_decay = 1e-4
momentum = 0.5

# %%
#################################### Input Data ################################
train_dataset = qaml.datasets.OptDigits(root='./data/', train=True,
                                     transform=torch_transforms.Compose([
                                     torch_transforms.ToTensor(),
                                     lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                     target_transform=torch_transforms.Compose([
                                     lambda x:torch.LongTensor([x.astype(int)]),
                                     lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                     download=True)

train_idx = [i for i,y in enumerate(train_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(train_idx)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE,
                                           sampler=sampler)

fig,axs = plt.subplots(4,5)
subdataset = zip(train_dataset.data[train_idx],train_dataset.targets[train_idx])
for ax,(img,label) in zip(axs.flat,subdataset):
    ax.matshow(img>0.5)
    ax.set_title(int(label))
    ax.axis('off')
plt.tight_layout()


test_dataset = qaml.datasets.OptDigits(root='./data/', train=False,
                                    transform=torch_transforms.Compose([
                                    torch_transforms.ToTensor(),
                                    lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                    target_transform=torch_transforms.Compose([
                                    lambda x:torch.LongTensor([x.astype(int)]),
                                    lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                    download=True)

test_idx = [i for i,y in enumerate(test_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(test_idx)
test_loader = torch.utils.data.DataLoader(test_dataset,sampler=sampler)
# Out:
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tra
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tes

# %%
################################# Model Definition #############################
VISIBLE_SIZE = DATA_SIZE + LABEL_SIZE
HIDDEN_SIZE = 16

# Specify model with dimensions
rbm = qaml.nn.RBM(VISIBLE_SIZE,HIDDEN_SIZE)

# Set up optimizer
optimizer = torch.optim.SGD(rbm.parameters(),
                            lr=learning_rate,
                            weight_decay=weight_decay,
                            momentum=momentum)

# Set up training mechanisms
gibbs_sampler = qaml.sampler.GibbsNetworkSampler(rbm)
CD = qaml.autograd.SampleBasedConstrastiveDivergence()

# %%
################################## Model Training ##############################
# Set the model to training mode
rbm.train()
err_log = []
accuracy_log = []
b_log = [rbm.b.detach().clone().numpy()]
c_log = [rbm.c.detach().clone().numpy()]
W_log = [rbm.W.detach().clone().numpy().flatten()]
for t in range(EPOCHS):
    epoch_error = torch.Tensor([0.])
    for img_batch, labels_batch in train_loader:
        input_data = torch.cat((img_batch.flatten(1),labels_batch.flatten(1)),1)

        # Positive Phase
        v0, prob_h0 = input_data, rbm(input_data)
        # Negative Phase
        vk, prob_hk = gibbs_sampler(v0,k=1)

        # Reconstruction error from Contrastive Divergence
        err = CD.apply((v0,prob_h0), (vk,prob_hk), *rbm.parameters())

        # Do not accumulated gradients
        optimizer.zero_grad()
        # Compute gradients. Save compute graph at last epoch
        err.backward(retain_graph = (t==EPOCHS-1))

        # Update parameters
        optimizer.step()
        epoch_error  += err

    # Error Log
    b_log.append(rbm.b.detach().clone().numpy())
    c_log.append(rbm.c.detach().clone().numpy())
    W_log.append(rbm.W.detach().clone().numpy().flatten())
    err_log.append(epoch_error.item())
    print(f"Epoch {t} Reconstruction Error = {epoch_error.item()}")

    ############################## CLASSIFICATION ##################################
    count = 0
    for i,(test_data, test_label) in enumerate(test_loader,start=10):
        prob_hk = rbm(torch.cat((test_data.flatten(1),torch.zeros(1,LABEL_SIZE)),dim=1))
        _,label_pred = rbm.generate(prob_hk).split((DATA_SIZE,LABEL_SIZE),dim=1)
        if label_pred.argmax() == test_label.argmax():
            count+=1
    accuracy_log.append(count/len(test_idx))
    print(f"Testing accuracy: {count}/{len(test_idx)} ({count/len(test_idx):.2f})")
# Out:
# Epoch 0 Reconstruction Error = 46.113258361816406
# Testing accuracy: 328/723 (0.45)
# Epoch 1 Reconstruction Error = 28.699682235717773
# Testing accuracy: 356/723 (0.49)
# Epoch 2 Reconstruction Error = 17.956632614135742
# Testing accuracy: 375/723 (0.52)
# Epoch 3 Reconstruction Error = 12.415672302246094
# Testing accuracy: 392/723 (0.54)
# Epoch 4 Reconstruction Error = 8.315092086791992
# Testing accuracy: 425/723 (0.59)
# Epoch 5 Reconstruction Error = 6.037006378173828
# Testing accuracy: 458/723 (0.63)
# Epoch 6 Reconstruction Error = 4.8722381591796875
# Testing accuracy: 435/723 (0.60)
# Epoch 7 Reconstruction Error = 4.345190048217773
# Testing accuracy: 420/723 (0.58)
# Epoch 8 Reconstruction Error = 3.998617172241211
# Testing accuracy: 464/723 (0.64)
# Epoch 9 Reconstruction Error = 3.6354615688323975
# Testing accuracy: 501/723 (0.69)
# Epoch 10 Reconstruction Error = 3.1804261207580566
# Testing accuracy: 499/723 (0.69)
# Epoch 11 Reconstruction Error = 2.897549629211426
# Testing accuracy: 491/723 (0.68)
# Epoch 12 Reconstruction Error = 2.613369941711426
# Testing accuracy: 493/723 (0.68)
# Epoch 13 Reconstruction Error = 2.361745595932007
# Testing accuracy: 491/723 (0.68)
# Epoch 14 Reconstruction Error = 2.2853267192840576
# Testing accuracy: 487/723 (0.67)
# Epoch 15 Reconstruction Error = 2.0384268760681152
# Testing accuracy: 513/723 (0.71)
# Epoch 16 Reconstruction Error = 1.9919476509094238
# Testing accuracy: 557/723 (0.77)
# Epoch 17 Reconstruction Error = 1.8650193214416504
# Testing accuracy: 583/723 (0.81)
# Epoch 18 Reconstruction Error = 1.8968784809112549
# Testing accuracy: 599/723 (0.83)
# Epoch 19 Reconstruction Error = 1.7685174942016602
# Testing accuracy: 605/723 (0.84)
# Epoch 20 Reconstruction Error = 1.5795307159423828
# Testing accuracy: 603/723 (0.83)
# Epoch 21 Reconstruction Error = 1.6271286010742188
# Testing accuracy: 606/723 (0.84)
# Epoch 22 Reconstruction Error = 1.7688326835632324
# Testing accuracy: 614/723 (0.85)
# Epoch 23 Reconstruction Error = 1.6690964698791504
# Testing accuracy: 619/723 (0.86)
# Epoch 24 Reconstruction Error = 1.6523457765579224
# Testing accuracy: 622/723 (0.86)
# Epoch 25 Reconstruction Error = 1.586366891860962
# Testing accuracy: 626/723 (0.87)
# Epoch 26 Reconstruction Error = 1.5636452436447144
# Testing accuracy: 629/723 (0.87)
# Epoch 27 Reconstruction Error = 1.6219191551208496
# Testing accuracy: 631/723 (0.87)
# Epoch 28 Reconstruction Error = 1.6955008506774902
# Testing accuracy: 637/723 (0.88)
# Epoch 29 Reconstruction Error = 1.4842228889465332
# Testing accuracy: 640/723 (0.89)
# Epoch 30 Reconstruction Error = 1.5419034957885742
# Testing accuracy: 645/723 (0.89)
# Epoch 31 Reconstruction Error = 1.567612886428833
# Testing accuracy: 646/723 (0.89)
# Epoch 32 Reconstruction Error = 1.4187822341918945
# Testing accuracy: 649/723 (0.90)
# Epoch 33 Reconstruction Error = 1.535106897354126
# Testing accuracy: 653/723 (0.90)
# Epoch 34 Reconstruction Error = 1.5097007751464844
# Testing accuracy: 653/723 (0.90)
# Epoch 35 Reconstruction Error = 1.4504399299621582
# Testing accuracy: 653/723 (0.90)
# Epoch 36 Reconstruction Error = 1.3933756351470947
# Testing accuracy: 653/723 (0.90)
# Epoch 37 Reconstruction Error = 1.3949477672576904
# Testing accuracy: 651/723 (0.90)
# Epoch 38 Reconstruction Error = 1.378669023513794
# Testing accuracy: 651/723 (0.90)
# Epoch 39 Reconstruction Error = 1.3808026313781738
# Testing accuracy: 649/723 (0.90)
# Epoch 40 Reconstruction Error = 1.4503576755523682
# Testing accuracy: 648/723 (0.90)
# Epoch 41 Reconstruction Error = 1.4422889947891235
# Testing accuracy: 648/723 (0.90)
# Epoch 42 Reconstruction Error = 1.4966566562652588
# Testing accuracy: 648/723 (0.90)
# Epoch 43 Reconstruction Error = 1.445065975189209
# Testing accuracy: 648/723 (0.90)
# Epoch 44 Reconstruction Error = 1.3636478185653687
# Testing accuracy: 653/723 (0.90)
# Epoch 45 Reconstruction Error = 1.2651844024658203
# Testing accuracy: 654/723 (0.90)
# Epoch 46 Reconstruction Error = 1.339128017425537
# Testing accuracy: 656/723 (0.91)
# Epoch 47 Reconstruction Error = 1.269300937652588
# Testing accuracy: 656/723 (0.91)
# Epoch 48 Reconstruction Error = 1.2522093057632446
# Testing accuracy: 655/723 (0.91)
# Epoch 49 Reconstruction Error = 1.2483816146850586
# Testing accuracy: 655/723 (0.91)
# Epoch 50 Reconstruction Error = 1.3280669450759888
# Testing accuracy: 657/723 (0.91)
# Epoch 51 Reconstruction Error = 1.3728493452072144
# Testing accuracy: 657/723 (0.91)
# Epoch 52 Reconstruction Error = 1.2068045139312744
# Testing accuracy: 657/723 (0.91)
# Epoch 53 Reconstruction Error = 1.2831659317016602
# Testing accuracy: 656/723 (0.91)
# Epoch 54 Reconstruction Error = 1.1744163036346436
# Testing accuracy: 656/723 (0.91)
# Epoch 55 Reconstruction Error = 1.277231216430664
# Testing accuracy: 657/723 (0.91)
# Epoch 56 Reconstruction Error = 1.3654364347457886
# Testing accuracy: 658/723 (0.91)
# Epoch 57 Reconstruction Error = 1.2997770309448242
# Testing accuracy: 660/723 (0.91)
# Epoch 58 Reconstruction Error = 1.28805673122406
# Testing accuracy: 659/723 (0.91)
# Epoch 59 Reconstruction Error = 1.220003366470337
# Testing accuracy: 660/723 (0.91)
# Epoch 60 Reconstruction Error = 1.0171059370040894
# Testing accuracy: 662/723 (0.92)
# Epoch 61 Reconstruction Error = 1.2563117742538452
# Testing accuracy: 663/723 (0.92)
# Epoch 62 Reconstruction Error = 1.0973236560821533
# Testing accuracy: 662/723 (0.92)
# Epoch 63 Reconstruction Error = 1.1719729900360107
# Testing accuracy: 664/723 (0.92)
# Epoch 64 Reconstruction Error = 1.1399199962615967
# Testing accuracy: 664/723 (0.92)
# Epoch 65 Reconstruction Error = 1.2952553033828735
# Testing accuracy: 665/723 (0.92)
# Epoch 66 Reconstruction Error = 1.1455395221710205
# Testing accuracy: 665/723 (0.92)
# Epoch 67 Reconstruction Error = 1.101396918296814
# Testing accuracy: 665/723 (0.92)
# Epoch 68 Reconstruction Error = 1.204386591911316
# Testing accuracy: 665/723 (0.92)
# Epoch 69 Reconstruction Error = 1.0573312044143677
# Testing accuracy: 664/723 (0.92)
# Epoch 70 Reconstruction Error = 1.0492498874664307
# Testing accuracy: 664/723 (0.92)
# Epoch 71 Reconstruction Error = 1.1937391757965088
# Testing accuracy: 663/723 (0.92)
# Epoch 72 Reconstruction Error = 1.0651013851165771
# Testing accuracy: 664/723 (0.92)
# Epoch 73 Reconstruction Error = 1.0549695491790771
# Testing accuracy: 664/723 (0.92)
# Epoch 74 Reconstruction Error = 1.0103826522827148
# Testing accuracy: 665/723 (0.92)

# %%
############################ MODEL VISUALIZATION ###############################

# Accuracy graph
fig, ax = plt.subplots()
ax.plot(accuracy_log)
plt.ylabel("Testing Accuracy")
plt.xlabel("Epoch")

# L1 error graph
fig, ax = plt.subplots()
ax.plot(err_log)
plt.ylabel("Reconstruction Error")
plt.xlabel("Epoch")
plt.savefig("classical_err_log.pdf")

# Visible bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',DATA_SIZE).colors))
lc_v = ax.plot(b_log)
plt.legend(iter(lc_v),[f'b{i}' for i in range(DATA_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Visible Biases")
plt.xlabel("Epoch")
plt.savefig("classical_visible_bias_log.pdf")

# Hidden bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE).colors))
lc_h = plt.plot(c_log)
plt.legend(lc_h,[f'c{i}' for i in range(HIDDEN_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Hidden Biases")
plt.xlabel("Epoch")
plt.savefig("classical_hidden_bias_log.pdf")

# Weights graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE*DATA_SIZE).colors))
lc_w = plt.plot(W_log)
plt.legend(lc_w,[f'w{i},{j}' for j in range(HIDDEN_SIZE) for i in range(DATA_SIZE)],ncol=4,bbox_to_anchor=(1,1))
plt.ylabel("Weights")
plt.xlabel("Epoch")
plt.savefig("classical_weights_log.pdf")

# %%
################################## VISUALIZE ###################################
plt.matshow(rbm.b.detach()[:DATA_SIZE].view(*SHAPE), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()

fig,axs = plt.subplots(HIDDEN_SIZE//4,4)
for i,ax in enumerate(axs.flat):
    weight_matrix = rbm.W[i].detach()[:DATA_SIZE].view(*SHAPE)
    ms = ax.matshow(weight_matrix, cmap='viridis', vmin=-1, vmax=1)
    ax.axis('off')
cbar = fig.colorbar(ms, ax=axs.ravel().tolist(), shrink=0.95)
plt.savefig("classical_weights.png")
