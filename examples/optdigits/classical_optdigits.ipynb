# %% [markdown]
# # Classical RBM training on the OptDigits Dataset for reconstruction and classification
# This is an example on classical Gibbs training of an RBM on the OptDigits
# dataset.
# Developed by: Jose Pinilla

# %%
# Required packages
import qaml
import torch
torch.manual_seed(0) # For deterministic weights

import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchvision.transforms as torch_transforms

# %%
################################# Hyperparameters ##############################
M,N = SHAPE = (8,8)
EPOCHS = 75
BATCH_SIZE = 1024
SUBCLASSES = [1,2,3,4]
DATA_SIZE = N*M
LABEL_SIZE = len(SUBCLASSES)
# Stochastic Gradient Descent
learning_rate = 0.1
weight_decay = 1e-4
momentum = 0.5

# %%
#################################### Input Data ################################
train_dataset = qaml.datasets.OptDigits(root='./data/', train=True,
                                     transform=torch_transforms.Compose([
                                     torch_transforms.ToTensor(),
                                     lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                     target_transform=torch_transforms.Compose([
                                     lambda x:torch.LongTensor([x.astype(int)]),
                                     lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                     download=True)

train_idx = [i for i,y in enumerate(train_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(train_idx)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE,
                                           sampler=sampler)

fig,axs = plt.subplots(4,5)
subdataset = zip(train_dataset.data[train_idx],train_dataset.targets[train_idx])
for ax,(img,label) in zip(axs.flat,subdataset):
    ax.matshow(img>0.5)
    ax.set_title(int(label))
    ax.axis('off')
plt.tight_layout()

test_dataset = qaml.datasets.OptDigits(root='./data/', train=False,
                                    transform=torch_transforms.Compose([
                                    torch_transforms.ToTensor(),
                                    lambda x:(x>0.5).to(x.dtype)]), #Binarize
                                    target_transform=torch_transforms.Compose([
                                    lambda x:torch.LongTensor([x.astype(int)]),
                                    lambda x:F.one_hot(x-1,len(SUBCLASSES))]),
                                    download=True)

test_idx = [i for i,y in enumerate(test_dataset.targets) if y in SUBCLASSES]
sampler = torch.utils.data.SubsetRandomSampler(test_idx)
test_loader = torch.utils.data.DataLoader(test_dataset,sampler=sampler)
# Out:
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tra
# Using downloaded and verified file ./data/OptDigits\raw\optdigits.tes

# %%
################################# Model Definition #############################
VISIBLE_SIZE = DATA_SIZE + LABEL_SIZE
HIDDEN_SIZE = 16

# Specify model with dimensions
rbm = qaml.nn.RBM(VISIBLE_SIZE,HIDDEN_SIZE)

# Initialize biases
_ = torch.nn.init.uniform_(rbm.c,-0.5,0.5)
_ = torch.nn.init.zeros_(rbm.c)
_ = torch.nn.init.uniform_(rbm.W,-0.5,0.5)

# Set up optimizer
optimizer = torch.optim.SGD(rbm.parameters(),
                            lr=learning_rate,
                            weight_decay=weight_decay,
                            momentum=momentum)

# Set up training mechanisms
beta = 1.0
gibbs_sampler = qaml.sampler.GibbsNetworkSampler(rbm,beta=beta)
CD = qaml.autograd.SampleBasedConstrastiveDivergence()

# %%
################################## Model Training ##############################
# Set the model to training mode
rbm.train()
err_log = []
accuracy_log = []
b_log = [rbm.b.detach().clone().numpy()]
c_log = [rbm.c.detach().clone().numpy()]
W_log = [rbm.W.detach().clone().numpy().flatten()]
for t in range(EPOCHS):
    epoch_error = torch.Tensor([0.])
    for img_batch, labels_batch in train_loader:
        input_data = torch.cat((img_batch.flatten(1),labels_batch.flatten(1)),1)

        # Positive Phase
        v0, prob_h0 = input_data, rbm(input_data,scale=beta)
        # Negative Phase
        vk, prob_hk = gibbs_sampler(v0,k=1)

        # Reconstruction error from Contrastive Divergence
        err = CD.apply((v0,prob_h0), (vk,prob_hk), *rbm.parameters())

        # Do not accumulated gradients
        optimizer.zero_grad()

        # Compute gradients
        err.backward()

        # Update parameters
        optimizer.step()
        epoch_error  += err

    # Error Log
    b_log.append(rbm.b.detach().clone().numpy())
    c_log.append(rbm.c.detach().clone().numpy())
    W_log.append(rbm.W.detach().clone().numpy().flatten())
    err_log.append(epoch_error.item())
    print(f"Epoch {t} Reconstruction Error = {epoch_error.item()}")

    ############################## CLASSIFICATION ##################################
    count = 0
    for i,(test_data, test_label) in enumerate(test_loader,start=10):
        recon_data = torch.cat((test_data.flatten(1),torch.zeros(1,LABEL_SIZE)),dim=1)
        recon_hk = rbm(recon_data,scale=beta)
        _,label_pred = rbm.generate(recon_hk,scale=beta).split((DATA_SIZE,LABEL_SIZE),dim=1)
        if label_pred.argmax() == test_label.argmax():
            count+=1
    accuracy_log.append(count/len(test_idx))
    print(f"Testing accuracy: {count}/{len(test_idx)} ({count/len(test_idx):.2f})")
# Out:
# Epoch 0 Reconstruction Error = 39.48319625854492
# Testing accuracy: 182/723 (0.25)
# Epoch 1 Reconstruction Error = 25.29671859741211
# Testing accuracy: 184/723 (0.25)
# Epoch 2 Reconstruction Error = 14.520723342895508
# Testing accuracy: 186/723 (0.26)
# Epoch 3 Reconstruction Error = 10.059653282165527
# Testing accuracy: 231/723 (0.32)
# Epoch 4 Reconstruction Error = 7.877302646636963
# Testing accuracy: 294/723 (0.41)
# Epoch 5 Reconstruction Error = 6.0352559089660645
# Testing accuracy: 366/723 (0.51)
# Epoch 6 Reconstruction Error = 4.919406414031982
# Testing accuracy: 410/723 (0.57)
# Epoch 7 Reconstruction Error = 4.355863571166992
# Testing accuracy: 444/723 (0.61)
# Epoch 8 Reconstruction Error = 3.8416972160339355
# Testing accuracy: 477/723 (0.66)
# Epoch 9 Reconstruction Error = 3.4519762992858887
# Testing accuracy: 519/723 (0.72)
# Epoch 10 Reconstruction Error = 3.1320109367370605
# Testing accuracy: 541/723 (0.75)
# Epoch 11 Reconstruction Error = 2.813796281814575
# Testing accuracy: 551/723 (0.76)
# Epoch 12 Reconstruction Error = 2.598458766937256
# Testing accuracy: 561/723 (0.78)
# Epoch 13 Reconstruction Error = 2.4396486282348633
# Testing accuracy: 571/723 (0.79)
# Epoch 14 Reconstruction Error = 2.333815336227417
# Testing accuracy: 575/723 (0.80)
# Epoch 15 Reconstruction Error = 2.2623748779296875
# Testing accuracy: 580/723 (0.80)
# Epoch 16 Reconstruction Error = 2.2824251651763916
# Testing accuracy: 590/723 (0.82)
# Epoch 17 Reconstruction Error = 2.0652880668640137
# Testing accuracy: 597/723 (0.83)
# Epoch 18 Reconstruction Error = 2.0591187477111816
# Testing accuracy: 599/723 (0.83)
# Epoch 19 Reconstruction Error = 1.913236379623413
# Testing accuracy: 597/723 (0.83)
# Epoch 20 Reconstruction Error = 1.7479782104492188
# Testing accuracy: 597/723 (0.83)
# Epoch 21 Reconstruction Error = 1.7127048969268799
# Testing accuracy: 601/723 (0.83)
# Epoch 22 Reconstruction Error = 1.7764066457748413
# Testing accuracy: 606/723 (0.84)
# Epoch 23 Reconstruction Error = 1.699089765548706
# Testing accuracy: 612/723 (0.85)
# Epoch 24 Reconstruction Error = 1.691369652748108
# Testing accuracy: 612/723 (0.85)
# Epoch 25 Reconstruction Error = 1.9340118169784546
# Testing accuracy: 614/723 (0.85)
# Epoch 26 Reconstruction Error = 1.7006070613861084
# Testing accuracy: 624/723 (0.86)
# Epoch 27 Reconstruction Error = 1.556751012802124
# Testing accuracy: 626/723 (0.87)
# Epoch 28 Reconstruction Error = 1.6092569828033447
# Testing accuracy: 629/723 (0.87)
# Epoch 29 Reconstruction Error = 1.4916878938674927
# Testing accuracy: 631/723 (0.87)
# Epoch 30 Reconstruction Error = 1.4070310592651367
# Testing accuracy: 635/723 (0.88)
# Epoch 31 Reconstruction Error = 1.4740355014801025
# Testing accuracy: 636/723 (0.88)
# Epoch 32 Reconstruction Error = 1.4235308170318604
# Testing accuracy: 639/723 (0.88)
# Epoch 33 Reconstruction Error = 1.4545830488204956
# Testing accuracy: 639/723 (0.88)
# Epoch 34 Reconstruction Error = 1.4260492324829102
# Testing accuracy: 638/723 (0.88)
# Epoch 35 Reconstruction Error = 1.4245734214782715
# Testing accuracy: 638/723 (0.88)
# Epoch 36 Reconstruction Error = 1.2419157028198242
# Testing accuracy: 638/723 (0.88)
# Epoch 37 Reconstruction Error = 1.4014859199523926
# Testing accuracy: 639/723 (0.88)
# Epoch 38 Reconstruction Error = 1.2364557981491089
# Testing accuracy: 639/723 (0.88)
# Epoch 39 Reconstruction Error = 1.1998162269592285
# Testing accuracy: 639/723 (0.88)
# Epoch 40 Reconstruction Error = 1.2253239154815674
# Testing accuracy: 643/723 (0.89)
# Epoch 41 Reconstruction Error = 1.306718111038208
# Testing accuracy: 642/723 (0.89)
# Epoch 42 Reconstruction Error = 1.460867166519165
# Testing accuracy: 643/723 (0.89)
# Epoch 43 Reconstruction Error = 1.295425534248352
# Testing accuracy: 642/723 (0.89)
# Epoch 44 Reconstruction Error = 1.293512225151062
# Testing accuracy: 642/723 (0.89)
# Epoch 45 Reconstruction Error = 1.2127892971038818
# Testing accuracy: 644/723 (0.89)
# Epoch 46 Reconstruction Error = 1.2181410789489746
# Testing accuracy: 646/723 (0.89)
# Epoch 47 Reconstruction Error = 1.179904580116272
# Testing accuracy: 649/723 (0.90)
# Epoch 48 Reconstruction Error = 1.0902763605117798
# Testing accuracy: 651/723 (0.90)
# Epoch 49 Reconstruction Error = 1.1257357597351074
# Testing accuracy: 651/723 (0.90)
# Epoch 50 Reconstruction Error = 1.3294569253921509
# Testing accuracy: 652/723 (0.90)
# Epoch 51 Reconstruction Error = 1.1142680644989014
# Testing accuracy: 650/723 (0.90)
# Epoch 52 Reconstruction Error = 1.1867499351501465
# Testing accuracy: 651/723 (0.90)
# Epoch 53 Reconstruction Error = 1.2806681394577026
# Testing accuracy: 652/723 (0.90)
# Epoch 54 Reconstruction Error = 1.034869909286499
# Testing accuracy: 652/723 (0.90)
# Epoch 55 Reconstruction Error = 1.2774629592895508
# Testing accuracy: 653/723 (0.90)
# Epoch 56 Reconstruction Error = 1.1119438409805298
# Testing accuracy: 653/723 (0.90)
# Epoch 57 Reconstruction Error = 0.9925879240036011
# Testing accuracy: 655/723 (0.91)
# Epoch 58 Reconstruction Error = 1.1098577976226807
# Testing accuracy: 654/723 (0.90)
# Epoch 59 Reconstruction Error = 1.059826374053955
# Testing accuracy: 655/723 (0.91)
# Epoch 60 Reconstruction Error = 1.097921371459961
# Testing accuracy: 656/723 (0.91)
# Epoch 61 Reconstruction Error = 1.0608241558074951
# Testing accuracy: 656/723 (0.91)
# Epoch 62 Reconstruction Error = 1.1206861734390259
# Testing accuracy: 656/723 (0.91)
# Epoch 63 Reconstruction Error = 1.0344218015670776
# Testing accuracy: 657/723 (0.91)
# Epoch 64 Reconstruction Error = 1.0225142240524292
# Testing accuracy: 659/723 (0.91)
# Epoch 65 Reconstruction Error = 0.8591535091400146
# Testing accuracy: 658/723 (0.91)
# Epoch 66 Reconstruction Error = 0.9683650135993958
# Testing accuracy: 659/723 (0.91)
# Epoch 67 Reconstruction Error = 1.032223105430603
# Testing accuracy: 660/723 (0.91)
# Epoch 68 Reconstruction Error = 0.8280420303344727
# Testing accuracy: 658/723 (0.91)
# Epoch 69 Reconstruction Error = 1.081749677658081
# Testing accuracy: 659/723 (0.91)
# Epoch 70 Reconstruction Error = 1.0420238971710205
# Testing accuracy: 660/723 (0.91)
# Epoch 71 Reconstruction Error = 1.0414271354675293
# Testing accuracy: 659/723 (0.91)
# Epoch 72 Reconstruction Error = 1.0265660285949707
# Testing accuracy: 659/723 (0.91)
# Epoch 73 Reconstruction Error = 0.9990741014480591
# Testing accuracy: 659/723 (0.91)
# Epoch 74 Reconstruction Error = 0.9539246559143066
# Testing accuracy: 660/723 (0.91)

# %%
############################ MODEL VISUALIZATION ###############################

# Testing accuracy graph
fig, ax = plt.subplots()
ax.plot(accuracy_log)
plt.ylabel("Testing Accuracy")
plt.xlabel("Epoch")
plt.savefig("classical_accuracy.pdf")

# L1 error graph
fig, ax = plt.subplots()
ax.plot(err_log)
plt.ylabel("Reconstruction Error")
plt.xlabel("Epoch")
plt.savefig("classical_err_log.pdf")

# Visible bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',DATA_SIZE).colors))
lc_v = ax.plot(b_log)
plt.legend(iter(lc_v),[f'b{i}' for i in range(DATA_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Visible Biases")
plt.xlabel("Epoch")
plt.savefig("classical_visible_bias_log.pdf")

# Hidden bias graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE).colors))
lc_h = plt.plot(c_log)
plt.legend(lc_h,[f'c{i}' for i in range(HIDDEN_SIZE)],ncol=2,bbox_to_anchor=(1,1))
plt.ylabel("Hidden Biases")
plt.xlabel("Epoch")
plt.savefig("classical_hidden_bias_log.pdf")

# Weights graph
fig, ax = plt.subplots()
ax.set_prop_cycle('color', list(plt.get_cmap('turbo',HIDDEN_SIZE*DATA_SIZE).colors))
lc_w = plt.plot(W_log)
plt.ylabel("Weights")
plt.xlabel("Epoch")
plt.savefig("classical_weights_log.pdf")

# %%
################################## VISUALIZE ###################################
plt.matshow(rbm.b.detach()[:DATA_SIZE].view(*SHAPE), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()

fig,axs = plt.subplots(HIDDEN_SIZE//4,4)
for i,ax in enumerate(axs.flat):
    weight_matrix = rbm.W[i].detach()[:DATA_SIZE].view(*SHAPE)
    ms = ax.matshow(weight_matrix, cmap='viridis', vmin=-1, vmax=1)
    ax.axis('off')
cbar = fig.colorbar(ms, ax=axs.ravel().tolist(), shrink=0.95)
plt.savefig("classical_weights.pdf")
